# %% [markdown]
# # TASK 1 - Python Date Structures

# %% [markdown]
# ## List

# %% [markdown]
# ### 1.Append

# %%
user_number=[89,90,78,56]
user_number.append(25)
print(user_number)
# Out:
# [89, 90, 78, 56, 25]

# %%
fruits=["apple","strawberry","Rice"]
fruits.append("Milk")
print(fruits)
# Out:
# ['apple', 'strawberry', 'Rice', 'Milk']

# %% [markdown]
# ### 2.Insert

# %%
colors = ["red", "green", "yellow"]
colors.insert(1,"blue")
print(colors)
# Out:
# ['red', 'blue', 'green', 'yellow']

# %% [markdown]
# ### 3.Remove

# %%
animals=["dog","cat","rabbit"]
animals.remove("cat")
print(animals)
# Out:
# ['dog', 'rabbit']

# %% [markdown]
# ### 4.Pop

# %%
numbers=[21,31,41,51,61]
popped_value=numbers.pop(-1)
print("Popped value:" ,popped_value)
print("Updated list:",numbers)
# Out:
# Popped value: 61
# Updated list: [21, 31, 41, 51]

# %% [markdown]
# ### 5.Sort

# %%
list_1=[12, 4, 67, 1]
list_1.sort()
print(list_1)
# Out:
# [1, 4, 12, 67]

# %%
name_list=["Zyed","Dhanjayan","Enian","Naresh","Tarunprasad","Arunkumar","Karthi"]
name_list.sort()
print(name_list)
# Out:
# ['Arunkumar', 'Dhanjayan', 'Enian', 'Karthi', 'Naresh', 'Tarunprasad', 'Zyed']

# %% [markdown]
# ### 6.Reverse

# %%
num_list=[1,2,3,45,6,7,44,22]
num_list.reverse()
print(num_list)
# Out:
# [22, 44, 7, 6, 45, 3, 2, 1]

# %% [markdown]
# ### 7.Index

# %%
fruits
# Out:
# ['apple', 'strawberry', 'Rice', 'Milk']

# %%
fruits[2]
# Out:
# 'Rice'

# %% [markdown]
# ### 8.Count

# %%
count_list=[2, 3, 2, 5, 2, 7]

# %%
count_list.count(2)
# Out:
# 3

# %% [markdown]
# ### 9.Extend

# %%
a=[1,2,3,4,5,6,7]
b=[22,33,44,55,66]

# %%
a.extend(b)

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 22, 33, 44, 55, 66]

# %% [markdown]
# ### 10.Clear

# %%
que=[1,2,3,4,5,6]
que.clear()
print(que)
# Out:
# []

# %% [markdown]
# ## Set

# %% [markdown]
# ### 1.Add

# %%
set_fruits={"Apple","Mango","strawberry"}
set_fruits.add("Pineapple")
print(set_fruits)
# Out:
# {'strawberry', 'Pineapple', 'Apple', 'Mango'}

# %%
set_fruits={"Apple","Mango","strawberry"}
set_fruits.add("Apple")
print(set_fruits)
# Out:
# {'strawberry', 'Apple', 'Mango'}

# %% [markdown]
# ### 2.Update

# %%
s={1,2,3,4}
s.update([8,9,6,5])
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 8, 9}

# %%
s.update("abc")
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 'a', 8, 9, 'b', 'c'}

# %% [markdown]
# ### 3.Remove

# %%
remove_set={5,6,7,8}
remove_set.remove(7)
print(remove_set)
# Out:
# {8, 5, 6}

# %% [markdown]
# ### 4.Discard

# %%
remove_set.discard(10)
print(remove_set)
# Out:
# {8, 6}

# %% [markdown]
# ### 5.Pop

# %%
h={1,2,3,4,5}
h.pop()
print(h)
# Out:
# {2, 3, 4, 5}

# %%
y={100}
y.pop()
print(y)
# Out:
# set()

# %% [markdown]
# ### 6.Clear

# %%
o={89,99}
o.clear()
print(o)
# Out:
# set()

# %%
o.add(10)
print(o)
# Out:
# {10}

# %%
q1={1,2,3}
q2=q1.copy()
q3=q1

# %%
q3
# Out:
# {1, 2, 3}

# %%
q2
# Out:
# {1, 2, 3}

# %%
q1
# Out:
# {1, 2, 3}

# %% [markdown]
# ### 7.Union

# %%
print({1,2,3,4,5}.union({2,3,4,5,6,7,8,9}))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
print({22,33}.union({88,99},{45,66}))
# Out:
# {33, 66, 99, 22, 88, 45}

# %% [markdown]
# ### 8.Intersection

# %%
print({1,2,3,4,5}.intersection({2,3,4}))
# Out:
# {2, 3, 4}

# %% [markdown]
# ### 9.Difference

# %%
print({2,3,4,5,}.difference({3,4}))
# Out:
# {2, 5}

# %% [markdown]
# ### 10.Symmetric_difference

# %%
print({1,2,3}.symmetric_difference({2,3}))
# Out:
# {1}

# %%
print({1,2}.symmetric_difference({1,2}))
# Out:
# set()

# %% [markdown]
# ### 11.issubset

# %%
print({1,2}.issubset({1,2,3,4}))
# Out:
# True

# %% [markdown]
# ### 12.issuperset

# %%
print({1,2,3,4}.issuperset({3}))
# Out:
# True

# %%
print({1,2,3,4}.issuperset({1,2,3}))
# Out:
# True

# %% [markdown]
# ### 13.isdisjoint

# %%
print({1,2,3}.isdisjoint({4}))
# Out:
# True

# %%
print({1,2,3}.isdisjoint({1}))
# Out:
# False

# %% [markdown]
# ## Tuples

# %% [markdown]
# ### 1.Count

# %%
nums = (1, 3, 5, 3, 3, 7, 1)

# %%
nums.count(3)
# Out:
# 3

# %% [markdown]
# ### 2.Index

# %%
fruits_0 = ('apple', 'banana', 'mango', 'orange')
fruits_0.index("mango")
# Out:
# 2

# %% [markdown]
# ## Dictioary

# %% [markdown]
# ### 1.Get

# %%
student = {"name": "Alex", "age": 20}
student.get("grade")

# %%
student.get("name")
# Out:
# 'Alex'

# %%
student.get("grade")

# %% [markdown]
# ### 2.Keys

# %%
student = {"name": "Alex", "age": 20}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %% [markdown]
# ### 3.Values

# %%
student = {"name": "Alex", "age": 20}

# %%
student.values()
# Out:
# dict_values(['Alex', 20])

# %% [markdown]
# ### 4.Items

# %%
d = {"x": 1, "y": 2}

# %%
d.items()
# Out:
# dict_items([('x', 1), ('y', 2)])

# %% [markdown]
# ### 5.Update

# %%
g={"a":1,"b":2}

# %%
g.update({"c":3})
print(g)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ### 6.Pop

# %%
g.pop("a")
# Out:
# 1

# %%
g
# Out:
# {'b': 2, 'c': 3}

# %% [markdown]
# ### 7.Popitem

# %%
g={"a":1,"k":3,"I":8}

# %%
g.popitem()
# Out:
# ('I', 8)

# %%
g
# Out:
# {'a': 1, 'k': 3}

# %% [markdown]
# ### 8.Setdefault

# %%
d={"name":"Arunkumar.M"}

# %%
d.setdefault("age",21)
# Out:
# 21

# %%
d
# Out:
# {'name': 'Arunkumar.M', 'age': 21}

# %% [markdown]
# ### 9.Clear

# %%
p = {"a": 1, "b": 2}

# %%
p
# Out:
# {'a': 1, 'b': 2}

# %%
p.clear()

# %%
p
# Out:
# {}

# %% [markdown]
# ### 10.Copy

# %%
a={"Name":"Arun","Age":21}

# %%
b=a

# %%
b
# Out:
# {'Name': 'Arun', 'Age': 21}

# %%
c=a.copy()

# %%
c
# Out:
# {'Name': 'Arun', 'Age': 21}

# %% [markdown]
# # TASK - 02 DATEFRAMES

# %% [markdown]
# ## 01

# %%
Rowing_ergomerter_timing={"Name" : ["Enian","Naresh","Arun","Ekshith","Tarun","Karthi"],"Timing" : [6.58,6.40,6.48,6.37,6.35,6.58],"Height":["185CM","185CM","190CM","190CM","188CM","175CM"] }

# %%
Rowing_ergomerter_timing
# Out:
# {'Name': ['Enian', 'Naresh', 'Arun', 'Ekshith', 'Tarun', 'Karthi'],
#  'Timing': [6.58, 6.4, 6.48, 6.37, 6.35, 6.58],
#  'Height': ['185CM', '185CM', '190CM', '190CM', '188CM', '175CM']}

# %%
import pandas as pd 

pd.DataFrame(Rowing_ergomerter_timing)
# Out:
#       Name  Timing Height
# 0    Enian    6.58  185CM
# 1   Naresh    6.40  185CM
# 2     Arun    6.48  190CM
# 3  Ekshith    6.37  190CM
# 4    Tarun    6.35  188CM
# 5   Karthi    6.58  175CM

# %% [markdown]
# ## 02

# %%
item_in_stock={"Item":["Rice","Tomato","Milk","Curd","Icecream"],"Stock":["500Kg","10","5L","3L","15Boxes"]}

# %%
pd.DataFrame(item_in_stock)
# Out:
#        Item    Stock
# 0      Rice    500Kg
# 1    Tomato       10
# 2      Milk       5L
# 3      Curd       3L
# 4  Icecream  15Boxes

# %% [markdown]
# ## 03

# %%
students_marks={"Name":["Arun","Naresh","Enian","Karthi"],"Social science":[88,80,90,85]}

# %%
pd.DataFrame(students_marks)
# Out:
#      Name  Social science
# 0    Arun              88
# 1  Naresh              80
# 2   Enian              90
# 3  Karthi              85

# %% [markdown]
# # THE END ---------------------------------------------------------------------
