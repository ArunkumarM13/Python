# %% [markdown]
# # Number guessing game Level 1

# %% [markdown]
# ##  Level.1 Print the user guessed number or not

# %%
secret_number=56

# %%
user_number=input("Enter the guess number:")
# Out:
# Enter the guess number: 20

# %%
secret_number=56

user_number=int(input("Enter the guess number:"))

if secret_number==user_number:
    print("congradulations! your guessed number is correct")
else:
    print("Sorry! Your guessed is wrong")
# Out:
# Enter the guess number: 56
# congradulations! your guessed number is correct

# %% [markdown]
# ## Importance of datetypes
#
# 1.Integer
#
# 2.Float
#
# 3.Boolean
#
# 4.String-"Anything which is enclosed in quotes"

# %% [markdown]
# ##  Level.2 Print the user guessed number or not but with max of 7 trails

# %% [markdown]
# ### 2.1 Using for Loop - end interation number is defined

# %%
secret_number=56

for i in range(0,7):
    user_number=int(input("Enter the guess number:"))
    
    if secret_number==user_number:
        print("congradulations! your guessed number is correct")
    else:
        print("Sorry! Your guessed is wrong")
# Out:
# Enter the guess number: 6
# Sorry! Your guessed is wrong
# Enter the guess number: 6
# Sorry! Your guessed is wrong
# Enter the guess number: 6
# Sorry! Your guessed is wrong
# Enter the guess number: 6
# Sorry! Your guessed is wrong
# Enter the guess number: 6
# Sorry! Your guessed is wrong
# Enter the guess number: 6
# Sorry! Your guessed is wrong
# Enter the guess number: 6
# Sorry! Your guessed is wrong

# %% [markdown]
# ### Using  Break

# %%
secret_number=56

for i in range(0,7):
    user_number=int(input("Enter the guess number:"))
    
    if secret_number==user_number:
        print("congradulations! your guessed number is correct")
        break
    else:
        print("Sorry! Your guessed is wrong")
# Out:
# Enter the guess number: 23
# Sorry! Your guessed is wrong
# Enter the guess number: 65
# Sorry! Your guessed is wrong
# Enter the guess number: 56
# congradulations! your guessed number is correct

# %% [markdown]
# ### Using while Loop - when the end number is not defined and the instrutions has to executed infinite times

# %%
secret_number=56

while True:
    user_number=int(input("Enter the guess number:"))
    
    if secret_number==user_number:
        print("congradulations! your guessed number is correct")
        break
    else:
        print("Sorry! Your guessed is wrong")
# Out:
# Enter the guess number: 23
# Sorry! Your guessed is wrong
# Enter the guess number: 35
# Sorry! Your guessed is wrong
# Enter the guess number: 45
# Sorry! Your guessed is wrong
# Enter the guess number: 56
# congradulations! your guessed number is correct

# %% [markdown]
# # Level 3.Give multiple conditions
#
# 1.User sholud enter the number 1 to 100.If the entered wrong,the program should say ,"Invaild number"
#
# 2.If the user guessed number > secret number,then program should say,"Your number is greater than the secret number"
#
# 3.If the user guessed number < secret number,then program should say,"Your number is lesser than the secret number"

# %%
print("Welcome to number guessing game")
print("Guess the number 1 to 100")

secret_number=56
    
for i in range(0,7):
    user_number=int(input("Enter the guess number:"))
    if user_number < 1 or user_number > 100:
        print("Invaild number! Please enter the number between 1 to 100")
    elif user_number > secret_number:
        print( "Your number is Higher")
    elif user_number < secret_number:
        print("Your number is lesser")
    else :
        print("Your Guessed Number is Correct")
        print(f"Congradulations, You have guessed the number {secret_number} in {i} attempts")
        break
# Out:
# Welcome to number guessing game
# Guess the number 1 to 100
# Enter the guess number: 46
# Your number is lesser
# Enter the guess number: 56
# Your Guessed Number is Correct
# Congradulations, You have guessed the number 56 in 1 attempts

# %% [markdown]
# ### Level 4.Setting Multipe conditions

# %%
print("Welcome to number guessing game")
print("Guess the number 1 to 100")

secret_number=56
    
for i in range(0,7):
    user_number=int(input("Enter the guess number:"))
    if user_number < 1 or user_number > 100:
        print("Invaild number! Please enter the number between 1 to 100")
    elif user_number > secret_number:
        print( "Your number is Higher")
    elif user_number < secret_number:
        print("Your number is lesser")
    else :
        print("Your Guessed Number is Correct")
        break
if secret_number == user_number:
    print(f"Congradulations, You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All the trails is exceeded. Try Again !!")
# Out:
# Welcome to number guessing game
# Guess the number 1 to 100
# Enter the guess number: 67
# Your number is Higher
# Enter the guess number: 67
# Your number is Higher
# Enter the guess number: 89
# Your number is Higher
# Enter the guess number: 76
# Your number is Higher
# Enter the guess number: 23
# Your number is lesser
# Enter the guess number: 33
# Your number is lesser
# Enter the guess number: 44
# Your number is lesser
# Sorry! All the trails is exceeded. Try Again !!

# %% [markdown]
# ## Level 5.1 The secret name should not be fixed . It should be Random

# %%
import random

# %%
secret_number=random.randint(1,100)

# %%
import random
print("Welcome to number guessing game")
print("Guess the number 1 to 100")

random.randint(1,100)
    
for i in range(0,7):
    user_number=int(input("Enter the guess number:"))
    if user_number < 1 or user_number > 100:
        print("Invaild number! Please enter the number between 1 to 100")
    elif user_number > secret_number:
        print( "Your number is Higher")
    elif user_number < secret_number:
        print("Your number is lesser")
    else :
        print("Your Guessed Number is Correct")
        break
if secret_number == user_number:
    print(f"Congradulations, You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All the trails is exceeded. Try Again !!")
# Out:
# Welcome to number guessing game
# Guess the number 1 to 100
# Enter the guess number: 45
# Your number is lesser
# Enter the guess number: 30
# Your number is lesser
# Enter the guess number: 15
# Your number is lesser
# Enter the guess number: 10
# Your number is lesser
# Enter the guess number: 5
# Your number is lesser
# Enter the guess number: 3
# Your number is lesser
# Enter the guess number: 2
# Your number is lesser
# Sorry! All the trails is exceeded. Try Again !!

# %% [markdown]
# ### 5.2 Take out the limits for try

# %%
import random
print("Welcome to number guessing game")
print("Guess the number 1 to 100")

random.randint(1,100)
    
while True:
    user_number=int(input("Enter the guess number:"))
    if user_number < 1 or user_number > 100:
        print("Invaild number! Please enter the number between 1 to 100")
    elif user_number > secret_number:
        print( "Your number is Higher")
    elif user_number < secret_number:
        print("Your number is lesser")
    else :
        print("Your Guessed Number is Correct")
        break
if secret_number == user_number:
    print(f"Congradulations, You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All the trails is exceeded. Try Again !!")
# Out:
# Welcome to number guessing game
# Guess the number 1 to 100
# Enter the guess number: 45
# Your number is lesser
# Enter the guess number: 464
# Invaild number! Please enter the number between 1 to 100
# Enter the guess number: 30
# Your number is lesser
# Enter the guess number: 15
# Your number is lesser
# Enter the guess number: 10
# Your number is lesser
# Enter the guess number: 5
# Your number is lesser
# Enter the guess number: 3
# Your number is lesser
# Enter the guess number: 2
# Your number is lesser
# Enter the guess number: 1
# Your number is lesser
# Enter the guess number: 0
# Invaild number! Please enter the number between 1 to 100
# Enter the guess number: 50
# Your number is lesser
# Enter the guess number: 70
# Your number is Higher
# Enter the guess number: 60
# Your number is Higher
# Enter the guess number: 55
# Your Guessed Number is Correct
# Congradulations, You have guessed the number 55 in 6 attempts

# %% [markdown]
# ### Level 6 - How to handle Invaild characters or values

# %%
import random
print("Welcome to number guessing game")
print("Guess the number 1 to 100")

random.randint(1,100)
    
for i in range(1,100):
    try:
        user_number=int(input("Enter the guess number:"))
        if user_number < 1 or user_number > 100:
            print("Invaild number! Please enter the number between 1 to 100")
        elif user_number > secret_number:
            print( "Your number is Higher")
        elif user_number < secret_number:
            print("Your number is lesser")
        else :
            print("Your Guessed Number is Correct")
            break
    except ValueError:
        print("Invaild Characters,Not recognized.Please enter the number between 1 to 100 to play this game")
if secret_number == user_number:
    print(f"Congradulations, You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All the trails is exceeded. Try Again !!")
# Out:
# Welcome to number guessing game
# Guess the number 1 to 100
# Enter the guess number: 34
# Your number is lesser
# Enter the guess number: nghghn
# Invaild Characters,Not recognized.Please enter the number between 1 to 100 to play this game
# Enter the guess number: 56
# Your number is Higher
# Enter the guess number: 45
# Your number is lesser
# Enter the guess number: 50
# Your number is lesser
# Enter the guess number: 55
# Your Guessed Number is Correct
# Congradulations, You have guessed the number 55 in 6 attempts

# %% [markdown]
# ## Level 7 - Take this program to run as a function when it called
#
# Step 1 - Define the Function
#
# Step 2 - Call the Function

# %%
def Number_Guessing_Game():
    import random
    print("Welcome to number guessing game")
    print("Guess the number 1 to 100")
    
    random.randint(1,100)
        
    for i in range(1,100):
        try:
            user_number=int(input("Enter the guess number:"))
            if user_number < 1 or user_number > 100:
                print("Invaild number! Please enter the number between 1 to 100")
            elif user_number > secret_number:
                print( "Your number is Higher")
            elif user_number < secret_number:
                print("Your number is lesser")
            else :
                print("Your Guessed Number is Correct")
                break
        except ValueError:
            print("Invaild Characters,Not recognized.Please enter the number between 1 to 100 to play this game")
    if secret_number == user_number:
        print(f"Congradulations, You have guessed the number {secret_number} in {i} attempts")
    else:
        print("Sorry! All the trails is exceeded. Try Again !!")

# %%
Number_Guessing_Game()
# Out:
# Welcome to number guessing game
# Guess the number 1 to 100
# Enter the guess number: 56
# Your number is Higher
# Enter the guess number: 45
# Your number is lesser
# Enter the guess number: 50
# Your number is lesser
# Enter the guess number: 55
# Your Guessed Number is Correct
# Congradulations, You have guessed the number 55 in 4 attempts
