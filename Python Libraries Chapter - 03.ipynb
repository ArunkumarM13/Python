# %% [markdown]
# # Python Libraries
#
# It is a set of functions,modules and classes where it has some pre-written codes to perform some tasks

# %% [markdown]
# ## 1.Pandas Library
#
# * For Date Analysis

# %%
pip install pandas
# pip - Preferred installer program
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd # Alias

# %%
pd.read_csv()

# %% [markdown]
# ## 2.Numpy Library - Numerical Operations

# %%
import numpy as np

# %% [markdown]
# ## 3.Matplotlib,Seaborn,Plotly
#
# * Date Visualizaton libraries

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
