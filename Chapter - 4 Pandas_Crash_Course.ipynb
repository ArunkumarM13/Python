# %% [markdown]
# # Chapter -01: Getting & Knowing your Data

# %%
import pandas as pd

# %%
hotel_order_details=pd.read_csv(filepath_or_buffer="data.tsv.txt",sep="\t")
hotel_order_details
# Out:
#           order_id  quantity                              item_name  \
# 0                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 2                1         1                       Nantucket Nectar
# 3                1         1  Chips and Tomatillo-Green Chili Salsa
# 4                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 4617          1833         1                          Steak Burrito
# 4618          1833         1                          Steak Burrito
# 4619          1834         1                     Chicken Salad Bowl
# 4620          1834         1                     Chicken Salad Bowl
# 4621          1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### 1.1 Perform Initial Analysis

# %%
# Function - ()
# Attribute

# %%
hotel_order_details.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Terminology Alert
#
# * Rows - Observations/Record.
# * Column - Features/Parameters

# %%
hotel_order_details.isnull().sum() #Chain of functions, Chain of commands
# Out:
#     order_id             0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
hotel_order_details.dtypes
# Out:
#     order_id           int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
hotel_order_details.describe(include="all")
# Out:
#             order_id     quantity     item_name choice_description item_price
# count    4622.000000  4622.000000          4622               3376       4622
# unique           NaN          NaN            50               1043         78
# top              NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq             NaN          NaN           726                134        730
# mean      927.254868     1.075725           NaN                NaN        NaN
# std       528.890796     0.410186           NaN                NaN        NaN
# min         1.000000     1.000000           NaN                NaN        NaN
# 25%       477.250000     1.000000           NaN                NaN        NaN
# 50%       926.000000     1.000000           NaN                NaN        NaN
# 75%      1393.000000     1.000000           NaN                NaN        NaN
# max      1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ## 1.2 Find out the Items sold in the Restaurent

# %%
hotel_order_details.nunique()
# Out:
#     order_id          1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
print(hotel_order_details["item_name"].unique())
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %% [markdown]
# ## 1.3 Give me the list of Top 5 Selling Items

# %%
hotel_order_details.groupby(by="item_name")["quantity"].sum().sort_values(ascending =False).head(10)  # Chain methods
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Name: quantity, dtype: int64

# %% [markdown]
# ## 1.3 Give me the list of Least 5 Selling Items

# %%
hotel_order_details.groupby(by="item_name")["quantity"].sum().sort_values().head(10)  # Chain methods
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Steak Salad                          4
# Bowl                                 4
# Burrito                              6
# Carnitas Salad Bowl                  6
# Veggie Salad                         6
# Name: quantity, dtype: int64

# %% [markdown]
# # Date Cleaning

# %%
hotel_order_details
# Out:
#           order_id  quantity                              item_name  \
# 0                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 2                1         1                       Nantucket Nectar
# 3                1         1  Chips and Tomatillo-Green Chili Salsa
# 4                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 4617          1833         1                          Steak Burrito
# 4618          1833         1                          Steak Burrito
# 4619          1834         1                     Chicken Salad Bowl
# 4620          1834         1                     Chicken Salad Bowl
# 4621          1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
hotel_order_details.dtypes
# Out:
#     order_id           int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
hotel_order_details["item_price"]=hotel_order_details["item_price"].str.replace("$","").astype(float) # Chain of Methods

# %%
hotel_order_details
# Out:
#           order_id  quantity                              item_name  \
# 0                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 2                1         1                       Nantucket Nectar
# 3                1         1  Chips and Tomatillo-Green Chili Salsa
# 4                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 4617          1833         1                          Steak Burrito
# 4618          1833         1                          Steak Burrito
# 4619          1834         1                     Chicken Salad Bowl
# 4620          1834         1                     Chicken Salad Bowl
# 4621          1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
hotel_order_details.dtypes
# Out:
#     order_id            int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
hotel_order_details.describe()
# Out:
#            order_id     quantity   item_price
# count   4622.000000  4622.000000  4622.000000
# mean     927.254868     1.075725     7.464336
# std      528.890796     0.410186     4.245557
# min        1.000000     1.000000     1.090000
# 25%      477.250000     1.000000     3.390000
# 50%      926.000000     1.000000     8.750000
# 75%     1393.000000     1.000000     9.250000
# max     1834.000000    15.000000    44.250000

# %%
hotel_order_details
# Out:
#           order_id  quantity                              item_name  \
# 0                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 2                1         1                       Nantucket Nectar
# 3                1         1  Chips and Tomatillo-Green Chili Salsa
# 4                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 4617          1833         1                          Steak Burrito
# 4618          1833         1                          Steak Burrito
# 4619          1834         1                     Chicken Salad Bowl
# 4620          1834         1                     Chicken Salad Bowl
# 4621          1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# ### Task

# %%
top_5_selling = hotel_order_details.groupby(by="item_name")["item_price"].sum().sort_values(ascending =False).head(5)

# %%
top_5_selling
# Out:
# item_name
# Chicken Bowl           7342.73
# Chicken Burrito        5575.82
# Steak Burrito          3851.43
# Steak Bowl             2260.19
# Chips and Guacamole    2201.04
# Name: item_price, dtype: float64

# %%
top_5_selling.sum()
# Out:
# np.float64(21231.21)

# %% [markdown]
# # Chapter 3 - Pandas Date Structure
#
# * 1D - Series
#
# * 2D - Dateframe

# %%
pd.Series(data=[4,5,6,7,8])
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# dtype: int64

# %%
pd.DataFrame({"Name":["Arun","Karthi","Enian","Naresh","Tarun"],"Ergomters Timing":["6.48","6.58","6.56","6.40","6.30"],"Height":["190Cm","175Cm","185Cm","184Cm","188Cm"],"Weight":[85,70,60,85,90]})
# Out:
#      Name Ergomters Timing Height  Weight
# 0    Arun             6.48  190Cm      85
# 1  Karthi             6.58  175Cm      70
# 2   Enian             6.56  185Cm      60
# 3  Naresh             6.40  184Cm      85
# 4   Tarun             6.30  188Cm      90

# %% [markdown]
# # Chapter - 4 Filtering & Selection & Sorting

# %%
import pandas as pd

# %%
euro_2012_date=pd.read_csv("Euro_2012_stats_TEAM.csv")
euro_2012_date
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012_date.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
### pd.set_option('display.max_columns',None) - For more details show of columns

# %%
filterred_euro=euro_2012_date[["Team","Goals","Yellow Cards", "Red Cards"]]
filterred_euro
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filterred_euro["Yellow Cards"]
# Out:
# 0      9
# 1      7
# 2      4
# 3      5
# 4      6
# 5      4
# 6      9
# 7     16
# 8      5
# 9      7
# 10    12
# 11     6
# 12     6
# 13    11
# 14     7
# 15     5
# Name: Yellow Cards, dtype: int64

# %% [markdown]
# ### 4.1 Top 5 Yellow Cards Team

# %%
filterred_euro.sort_values(by ="Yellow Cards",ascending=False).head()
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0
# 0    Croatia      4             9          0
# 6     Greece      5             9          1

# %% [markdown]
# ### 4.2 List the teams which has got Red cards

# %%
filterred_euro[filterred_euro["Red Cards"] == 1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %% [markdown]
# ### 4.3 List teams which has got more than 8 Yellow Cards

# %%
filterred_euro[filterred_euro["Yellow Cards"] >=8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %% [markdown]
# ### Chapter 05 - How to deal with Missing Values

# %%
import pandas as pd

# %%
proitbridge_employee_date=pd.read_csv("employee_data.csv")
proitbridge_employee_date
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %% [markdown]
# ## Level 1 Date Cleaning

# %% [markdown]
# ### Always Recommended : I will call to my client, and check with him if he can give the right data - Great!!!
#
# Incase,client is asking us to perform the Date cleaning operations.

# %% [markdown]
# ### Step 1 : Remove Duplicate entries/records

# %%
proitbridge_employee_date.drop_duplicates(inplace=True) # The complete operations will impact the original Dateset.

# %%
proitbridge_employee_date
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %%
proitbridge_employee_date.shape
# Out:
# (7, 5)

# %% [markdown]
# ### Step 2: Find out the Null Entries

# %%
proitbridge_employee_date.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %%
proitbridge_employee_date.dropna(inplace=True)

# %%
proitbridge_employee_date
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
proitbridge_employee_date.shape
# Out:
# (4, 5)

# %% [markdown]
# ### Step 3: Record in a Document
#
# * Client gave totally 7 Obseravations out of which 3 entries are removed because those records do not have complete information.
#
# ### Step 4: Get Approval
# * Send this to client and get the approval to proceed for Model Building or Model Training.

# %%
proitbridge_employee_date.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# ## Level 2 of Date Cleaning

# %%
import pandas as pd

# %%
pd.read_csv() #You cannot import multiple sheets if it's in one CSV file, you need to have seperate CSV file.

# %%
pd.read_excel() # You can import multiple sheets.
