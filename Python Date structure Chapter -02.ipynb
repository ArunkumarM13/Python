# %% [markdown]
# # Why Python Bulit-In Date Structures ?
#
# * To collect multiple date in a structure
#
#
# #### 4 Date structures in Python
#
# 1.List
#
# 2.Sets
#
# 3.Tuples
#
# 4.Dictionary - Key & Value

# %% [markdown]
# ## 1.List
#
# * 1D
#
# * Multiple values
#
# * Duplicate Values
#
# * Indexing & Slicing is Possible
#
# * Mutable

# %%
empty_list=[]

# %%
empty_list
# Out:
# []

# %%
type(empty_list)
# Out:
# list

# %%
item_buy=["apple","orange","milk","pomgranate",78,90,7.55]

# %%
item_buy
# Out:
# ['apple', 'orange', 'milk', 'pomgranate', 78, 90, 7.55]

# %%
type(item_buy)
# Out:
# list

# %%
len(item_buy)
# Out:
# 7

# %%
item_buy[2] # Indexing the value means []
# Out:
# 'milk'

# %%
item_buy[-1]
# Out:
# 7.55

# %%
item_buy[0:5]
# Out:
# ['apple', 'orange', 'milk', 'pomgranate', 78]

# %%
item_buy[2:7]
# Out:
# ['milk', 'pomgranate', 78, 90, 7.55]

# %%
item_buy[4]="Strawberry"

# %%
item_buy
# Out:
# ['apple', 'orange', 'milk', 'pomgranate', 'Strawberry', 90, 7.55]

# %% [markdown]
# ## 2. Sets
#
# * 1D
#
# * Multiple Values
#
# * It Won't Allow the duplicate values
#
# * Mutable

# %%
empty_sets=set()

# %%
empty_sets
# Out:
# set()

# %%
empty_sets={"Arun","Naresh","Enian","Karthi","Tarun"}
empty_sets
# Out:
# {'Arun', 'Enian', 'Karthi', 'Naresh', 'Tarun'}

# %%
type(empty_sets)
# Out:
# set

# %%
empty_sets[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 empty_sets[1]
#
# TypeError: 'set' object is not subscriptable

# %%
empty_sets[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 empty_sets[0:3]
#
# TypeError: 'set' object is not subscriptable

# %%
empty_sets[1]="singh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 empty_sets[1]="singh"
#
# TypeError: 'set' object does not support item assignment

# %%
empty_sets.add("Red Banana")

# %%
empty_sets
# Out:
# {'Arun', 'Enian', 'Karthi', 'Naresh', 'Red Banana', 'Tarun'}

# %% [markdown]
# ## Tuples
#
# * 1D
#
# * Multiple values
#
# * Duplicate values is allowed
#
# * Indexing and slicing is als allowed
#
# * Immutable

# %%
empty_tuples= ()

# %%
empty_tuples
# Out:
# ()

# %%
type(empty_tuples)
# Out:
# tuple

# %%
empty_tuples=("Rice","Tomato","Ginger","Oil","Tomato","Rice",45,67)
empty_tuples
# Out:
# ('Rice', 'Tomato', 'Ginger', 'Oil', 'Tomato', 'Rice', 45, 67)

# %%
empty_tuples[3]
# Out:
# 'Oil'

# %%
empty_tuples[0:4]
# Out:
# ('Rice', 'Tomato', 'Ginger', 'Oil')

# %%
empty_tuples[2]="carilic paste"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 empty_tuples[2]="carilic paste"
#
# TypeError: 'tuple' object does not support item assignment

# %%
empty_tuples.count("Rice")
# Out:
# 2

# %%
empty_tuples.index(45)
# Out:
# 6

# %% [markdown]
# ## 4. Dictionary
#
# It is a Key : Value Pair
#
# * 2D
#
# * Multiple Values
#
# * Mutable
#
# * Indexing & Slicing is not possiabel
#
# * Don't create duplicate key, but you can create duplicate values

# %%
empty_dic= {}
empty_dic
# Out:
# {}

# %%
type(empty_dic)
# Out:
# dict

# %%
students_marks={"Maths":90,"science":45,"Engish":88}

# %%
type(students_marks)
# Out:
# dict

# %%
iteam_buy={"Tomato":5,"Potato":4,"Apple":2}
iteam_buy
# Out:
# {'Tomato': 5, 'Potato': 4, 'Apple': 2}

# %%
type(iteam_buy)
# Out:
# dict

# %%
iteam_buy[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 iteam_buy[0]
#
# KeyError: 0

# %%
iteam_buy[0:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 iteam_buy[0:3]
#
# KeyError: slice(0, 3, None)

# %%
students_marks={"Names":["Arun","Naresh","Enian","Karthi","Tarun"],"Maths":[78,56,89,65,89],"Science":[45,68,99,49,60]}

# %%
students_marks
# Out:
# {'Names': ['Arun', 'Naresh', 'Enian', 'Karthi', 'Tarun'],
#  'Maths': [78, 56, 89, 65, 89],
#  'Science': [45, 68, 99, 49, 60]}

# %%
import pandas as pd 

pd.DataFrame(data=students_marks)
# Out:
#     Names  Maths  Science
# 0    Arun     78       45
# 1  Naresh     56       68
# 2   Enian     89       99
# 3  Karthi     65       49
# 4   Tarun     89       60

# %% [markdown]
# # THE END !!!
